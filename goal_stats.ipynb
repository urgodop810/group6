# %%
import numpy as np
import pandas as pd

# %%
competitions_df = pd.read_json('../Statsbomb/data/competitions.json')
competitions_df
# Out:
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# 11              16         39                    Europe
# 12              16         37                    Europe
# 13              16         44                    Europe
# 14              16         76                    Europe
# 15              37         90                   England
# ...

# %%
season = competitions_df[ (competitions_df.competition_name == "La Liga") & (competitions_df.season_name == "2020/2021") ]
season
# Out:
#     competition_id  season_id country_name competition_name  \
# 19              11         90        Spain          La Liga
#
#    competition_gender  competition_youth  competition_international  \
# 19               male              False                      False
#
#    season_name            match_updated           match_updated_360  \
# 19   2020/2021  2022-02-11T14:56:09.076  2021-10-30T04:19:36.116600
#
#            match_available_360          match_available
# 19  2021-09-17T15:18:33.787790  2022-02-11T14:56:09.076

# %%
matches = pd.read_json('../Statsbomb/data/matches/'+str(season.competition_id.iloc[0])+'/'+str(season.season_id.iloc[0])+'.json')

# %%
barcelona_matches = matches[ (matches.home_team.apply(pd.Series).home_team_name == "Barcelona") | (matches.away_team.apply(pd.Series).away_team_name == "Barcelona")]
barcelona_matches
# Out:
#     match_id  match_date      kick_off  \
# 0    3773369  2021-03-15  21:00:00.000
# 1    3773387  2021-05-11  22:00:00.000
# 2    3773372  2021-05-08  16:15:00.000
# 3    3773695  2021-05-02  21:00:00.000
# 4    3773586  2021-04-29  19:00:00.000
# 5    3773457  2021-05-16  18:30:00.000
# 6    3773377  2020-12-19  16:15:00.000
# 7    3773656  2020-11-21  21:00:00.000
# 8    3773565  2021-01-09  18:30:00.000
# 9    3773386  2020-10-31  21:00:00.000
# 10   3773587  2020-10-17  21:00:00.000
# 11   3773672  2020-10-04  21:00:00.000
# 12   3773585  2020-10-24  16:00:00.000
# 13   3773466  2020-10-01  21:30:00.000
# 14   3773552  2021-01-03  21:00:00.000
# 15   3773593  2020-09-27  21:00:00.000
# 16   3773660  2020-12-13  21:00:00.000
# 17   3773661  2021-04-22  22:00:00.000
# 18   3773597  2021-03-21  21:00:00.000
# 19   3773523  2020-12-16  21:00:00.000
# 20   3773571  2020-12-22  22:00:00.000
# 21   3773497  2021-04-10  21:00:00.000
# 22   3773631  2021-02-07  21:00:00.000
# ...

# %%
last_match = pd.read_json('../Statsbomb/data/events/'+str(barcelona_matches.iloc[-1].match_id)+'.json')
#last_match.shot.dropna().apply(pd.Series).outcome.apply(pd.Series)
# Out:
#        id     name
# 249    98    Off T
# 264    98    Off T
# 356   100    Saved
# 362    96  Blocked
# 389   100    Saved
# 495    98    Off T
# 734    98    Off T
# 916   100    Saved
# 954    97     Goal
# 1094   98    Off T
# 1275  100    Saved
# 1506   98    Off T
# 1835   97     Goal
# 1934   96  Blocked
# 2033   97     Goal
# 2259   96  Blocked
# 2294  100    Saved
# 2442   96  Blocked
# 2446   97     Goal
# 2903   98    Off T
# 2995   98    Off T
# 3024   97     Goal
# 3232  100    Saved
# 3400   97     Goal
# 3503   98    Off T
# 3547  100    Saved
# 3590   97     Goal
# 3620   98    Off T
# 3737  100    Saved

# %%
shot_outcomes = last_match.shot.dropna().apply(pd.Series).outcome.apply(pd.Series)
goals = shot_outcomes[shot_outcomes.name == "Goal"]

# %%
last_match.shot.dropna().apply(pd.Series)
# Out:
#       statsbomb_xg                        end_location  \
# 249       0.097125                  [120.0, 35.3, 0.2]
# 264       0.022353                  [120.0, 45.1, 0.9]
# 356       0.062647                  [119.4, 38.9, 2.2]
# 362       0.014313                       [103.6, 22.3]
# 389       0.049422                  [118.5, 44.2, 0.8]
# 495       0.063824                  [120.0, 44.5, 0.2]
# 734       0.043070                  [120.0, 50.8, 0.1]
# 916       0.016994                  [117.5, 42.0, 0.9]
# 954       0.043375                  [119.9, 37.9, 2.2]
# 1094      0.317803                  [120.0, 35.1, 0.2]
# 1275      0.760000                  [119.3, 37.9, 0.9]
# 1506      0.087759                  [120.0, 43.0, 4.5]
# 1835      0.267170                  [120.0, 38.2, 1.6]
# 1934      0.037329                       [105.7, 31.6]
# 2033      0.905517                  [120.0, 41.4, 0.2]
# 2259      0.050417                       [102.7, 29.7]
# ...
